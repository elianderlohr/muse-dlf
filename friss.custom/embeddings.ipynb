# %%
# !pip install torch transformers
# Out:
# Requirement already satisfied: torch in c:\users\elias\appdata\roaming\python\python310\site-packages (1.12.1)
# Requirement already satisfied: transformers in c:\users\elias\appdata\roaming\python\python310\site-packages (4.20.1)
# Requirement already satisfied: typing-extensions in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from torch) (4.5.0)
# Requirement already satisfied: filelock in c:\users\elias\appdata\roaming\python\python310\site-packages (from transformers) (3.7.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from transformers) (0.10.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: requests in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from transformers) (0.12.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from transformers) (4.66.1)
# Requirement already satisfied: colorama in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: allennlp in c:\users\elias\appdata\roaming\python\python310\site-packages (2.10.1)
# Requirement already satisfied: torch<1.13.0,>=1.10.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (1.12.1)
# Requirement already satisfied: torchvision<0.14.0,>=0.8.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.13.1)
# Requirement already satisfied: cached-path<1.2.0,>=1.1.3 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (1.1.6)
# Requirement already satisfied: fairscale==0.4.6 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.4.6)
# Requirement already satisfied: nltk>=3.6.5 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (3.8.1)
# Requirement already satisfied: spacy<3.4,>=2.1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (3.3.3)
# Requirement already satisfied: numpy>=1.21.4 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (1.24.3)
# Requirement already satisfied: tensorboardX>=1.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (2.6.2.2)
# Requirement already satisfied: requests>=2.28 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (2.31.0)
# Requirement already satisfied: tqdm>=4.62 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (4.66.1)
# Requirement already satisfied: h5py>=3.6.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (3.9.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (1.3.0)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (1.11.2)
# Requirement already satisfied: pytest>=6.2.5 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (7.4.2)
# Requirement already satisfied: transformers<4.21,>=4.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (4.20.1)
# Requirement already satisfied: sentencepiece>=0.1.96 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.1.99)
# Requirement already satisfied: filelock<3.8,>=3.3 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (3.7.1)
# Requirement already satisfied: lmdb>=1.2.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (1.4.1)
# Requirement already satisfied: more-itertools>=8.12.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (10.1.0)
# Requirement already satisfied: termcolor==1.1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (1.1.0)
# Requirement already satisfied: wandb<0.13.0,>=0.10.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.12.21)
# Requirement already satisfied: huggingface-hub>=0.0.16 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.10.1)
# Requirement already satisfied: dill>=0.3.4 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.3.6)
# Requirement already satisfied: base58>=2.1.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (2.1.1)
# Requirement already satisfied: sacremoses in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.0.53)
# Requirement already satisfied: typer>=0.4.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.4.2)
# Requirement already satisfied: protobuf<4.0.0,>=3.12.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (3.20.3)
# Requirement already satisfied: traitlets>5.1.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (5.7.1)
# Requirement already satisfied: rich<13.0,>=12.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from cached-path<1.2.0,>=1.1.3->allennlp) (12.6.0)
# Requirement already satisfied: boto3<2.0,>=1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from cached-path<1.2.0,>=1.1.3->allennlp) (1.28.53)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from cached-path<1.2.0,>=1.1.3->allennlp) (2.11.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.0.16->allennlp) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.0.16->allennlp) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.0.16->allennlp) (23.1)
# Requirement already satisfied: click in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from nltk>=3.6.5->allennlp) (8.1.7)
# Requirement already satisfied: joblib in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from nltk>=3.6.5->allennlp) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from nltk>=3.6.5->allennlp) (2023.8.8)
# Requirement already satisfied: iniconfig in c:\users\elias\appdata\roaming\python\python310\site-packages (from pytest>=6.2.5->allennlp) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\elias\appdata\roaming\python\python310\site-packages (from pytest>=6.2.5->allennlp) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pytest>=6.2.5->allennlp) (1.0.4)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from pytest>=6.2.5->allennlp) (2.0.1)
# Requirement already satisfied: colorama in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pytest>=6.2.5->allennlp) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests>=2.28->allennlp) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests>=2.28->allennlp) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests>=2.28->allennlp) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests>=2.28->allennlp) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from scikit-learn>=1.0.1->allennlp) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (2.0.9)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (1.8.2)
# Requirement already satisfied: jinja2 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp) (68.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (3.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from torchvision<0.14.0,>=0.8.1->allennlp) (10.0.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from transformers<4.21,>=4.1->allennlp) (0.12.1)
# Requirement already satisfied: GitPython>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (3.1.37)
# Requirement already satisfied: promise<3,>=2.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (2.3)
# Requirement already satisfied: shortuuid>=0.5.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.0.11)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (5.9.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.31.0)
# Requirement already satisfied: six>=1.13.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.16.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (0.4.0)
# Requirement already satisfied: pathtools in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (0.1.2)
# Requirement already satisfied: setproctitle in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.3.2)
# Requirement already satisfied: botocore<1.32.0,>=1.31.53 in c:\users\elias\appdata\roaming\python\python310\site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.31.53)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.6.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp) (4.0.10)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.23.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.11.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.6.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp) (2.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from jinja2->spacy<3.4,>=2.1.0->allennlp) (2.1.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from botocore<1.32.0,>=1.31.53->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.8.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp) (5.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.60.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-resumable-media>=2.6.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.5.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.5.0)

# %%
pip install allennlp
# Out:
# Requirement already satisfied: allennlp in c:\users\elias\appdata\roaming\python\python310\site-packages (2.10.1)
# Requirement already satisfied: torch<1.13.0,>=1.10.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (1.12.1)
# Requirement already satisfied: torchvision<0.14.0,>=0.8.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.13.1)
# Requirement already satisfied: cached-path<1.2.0,>=1.1.3 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (1.1.6)
# Requirement already satisfied: fairscale==0.4.6 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.4.6)
# Requirement already satisfied: nltk>=3.6.5 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (3.8.1)
# Requirement already satisfied: spacy<3.4,>=2.1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (3.3.3)
# Requirement already satisfied: numpy>=1.21.4 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (1.24.3)
# Requirement already satisfied: tensorboardX>=1.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (2.6.2.2)
# Requirement already satisfied: requests>=2.28 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (2.31.0)
# Requirement already satisfied: tqdm>=4.62 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (4.66.1)
# Requirement already satisfied: h5py>=3.6.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (3.9.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (1.3.0)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (1.11.2)
# Requirement already satisfied: pytest>=6.2.5 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (7.4.2)
# Requirement already satisfied: transformers<4.21,>=4.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (4.20.1)
# Requirement already satisfied: sentencepiece>=0.1.96 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.1.99)
# Requirement already satisfied: filelock<3.8,>=3.3 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (3.7.1)
# Requirement already satisfied: lmdb>=1.2.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (1.4.1)
# Requirement already satisfied: more-itertools>=8.12.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (10.1.0)
# Requirement already satisfied: termcolor==1.1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (1.1.0)
# Requirement already satisfied: wandb<0.13.0,>=0.10.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.12.21)
# Requirement already satisfied: huggingface-hub>=0.0.16 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.10.1)
# Requirement already satisfied: dill>=0.3.4 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.3.6)
# Requirement already satisfied: base58>=2.1.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (2.1.1)
# Requirement already satisfied: sacremoses in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.0.53)
# Requirement already satisfied: typer>=0.4.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (0.4.2)
# Requirement already satisfied: protobuf<4.0.0,>=3.12.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp) (3.20.3)
# Requirement already satisfied: traitlets>5.1.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp) (5.7.1)
# Requirement already satisfied: rich<13.0,>=12.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from cached-path<1.2.0,>=1.1.3->allennlp) (12.6.0)
# Requirement already satisfied: boto3<2.0,>=1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from cached-path<1.2.0,>=1.1.3->allennlp) (1.28.53)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from cached-path<1.2.0,>=1.1.3->allennlp) (2.11.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.0.16->allennlp) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.0.16->allennlp) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from huggingface-hub>=0.0.16->allennlp) (23.1)
# Requirement already satisfied: click in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from nltk>=3.6.5->allennlp) (8.1.7)
# Requirement already satisfied: joblib in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from nltk>=3.6.5->allennlp) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from nltk>=3.6.5->allennlp) (2023.8.8)
# Requirement already satisfied: iniconfig in c:\users\elias\appdata\roaming\python\python310\site-packages (from pytest>=6.2.5->allennlp) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\elias\appdata\roaming\python\python310\site-packages (from pytest>=6.2.5->allennlp) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pytest>=6.2.5->allennlp) (1.0.4)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from pytest>=6.2.5->allennlp) (2.0.1)
# Requirement already satisfied: colorama in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pytest>=6.2.5->allennlp) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests>=2.28->allennlp) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests>=2.28->allennlp) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests>=2.28->allennlp) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests>=2.28->allennlp) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from scikit-learn>=1.0.1->allennlp) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (2.0.9)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (1.8.2)
# Requirement already satisfied: jinja2 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp) (68.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp) (3.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from torchvision<0.14.0,>=0.8.1->allennlp) (10.0.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from transformers<4.21,>=4.1->allennlp) (0.12.1)
# Requirement already satisfied: GitPython>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (3.1.37)
# Requirement already satisfied: promise<3,>=2.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (2.3)
# Requirement already satisfied: shortuuid>=0.5.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.0.11)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (5.9.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.31.0)
# Requirement already satisfied: six>=1.13.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.16.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (0.4.0)
# Requirement already satisfied: pathtools in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (0.1.2)
# Requirement already satisfied: setproctitle in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.3.2)
# Requirement already satisfied: botocore<1.32.0,>=1.31.53 in c:\users\elias\appdata\roaming\python\python310\site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.31.53)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.6.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp) (4.0.10)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.23.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.11.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.6.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp) (2.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from jinja2->spacy<3.4,>=2.1.0->allennlp) (2.1.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from botocore<1.32.0,>=1.31.53->boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp) (2.8.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp) (5.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.60.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-resumable-media>=2.6.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (1.5.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp) (0.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install allennlp_models
# Out:
# Requirement already satisfied: allennlp_models in c:\users\elias\appdata\roaming\python\python310\site-packages (2.10.1)
# Requirement already satisfied: torch<1.13.0,>=1.7.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp_models) (1.12.1)
# Requirement already satisfied: conllu==4.4.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp_models) (4.4.2)
# Requirement already satisfied: word2number>=1.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp_models) (1.1)
# Requirement already satisfied: py-rouge==1.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp_models) (1.1)
# Requirement already satisfied: nltk>=3.6.5 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp_models) (3.8.1)
# Requirement already satisfied: ftfy in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp_models) (6.1.1)
# Requirement already satisfied: datasets in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp_models) (2.10.1)
# Requirement already satisfied: allennlp<2.11,>=2.10.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp_models) (2.10.1)
# Requirement already satisfied: torchvision<0.14.0,>=0.8.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (0.13.1)
# Requirement already satisfied: cached-path<1.2.0,>=1.1.3 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (1.1.6)
# Requirement already satisfied: fairscale==0.4.6 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (0.4.6)
# Requirement already satisfied: spacy<3.4,>=2.1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (3.3.3)
# Requirement already satisfied: numpy>=1.21.4 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (1.24.3)
# Requirement already satisfied: tensorboardX>=1.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (2.6.2.2)
# Requirement already satisfied: requests>=2.28 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (2.31.0)
# Requirement already satisfied: tqdm>=4.62 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (4.66.1)
# Requirement already satisfied: h5py>=3.6.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (3.9.0)
# Requirement already satisfied: scikit-learn>=1.0.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (1.3.0)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (1.11.2)
# Requirement already satisfied: pytest>=6.2.5 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (7.4.2)
# Requirement already satisfied: transformers<4.21,>=4.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (4.20.1)
# Requirement already satisfied: sentencepiece>=0.1.96 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (0.1.99)
# Requirement already satisfied: filelock<3.8,>=3.3 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (3.7.1)
# Requirement already satisfied: lmdb>=1.2.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (1.4.1)
# Requirement already satisfied: more-itertools>=8.12.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (10.1.0)
# Requirement already satisfied: termcolor==1.1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (1.1.0)
# Requirement already satisfied: wandb<0.13.0,>=0.10.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (0.12.21)
# Requirement already satisfied: huggingface-hub>=0.0.16 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (0.10.1)
# Requirement already satisfied: dill>=0.3.4 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (0.3.6)
# Requirement already satisfied: base58>=2.1.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (2.1.1)
# Requirement already satisfied: sacremoses in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (0.0.53)
# Requirement already satisfied: typer>=0.4.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (0.4.2)
# Requirement already satisfied: protobuf<4.0.0,>=3.12.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (3.20.3)
# Requirement already satisfied: traitlets>5.1.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from allennlp<2.11,>=2.10.1->allennlp_models) (5.7.1)
# Requirement already satisfied: click in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from nltk>=3.6.5->allennlp_models) (8.1.7)
# Requirement already satisfied: joblib in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from nltk>=3.6.5->allennlp_models) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from nltk>=3.6.5->allennlp_models) (2023.8.8)
# Requirement already satisfied: typing-extensions in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from torch<1.13.0,>=1.7.0->allennlp_models) (4.5.0)
# Requirement already satisfied: pyarrow>=6.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from datasets->allennlp_models) (13.0.0)
# Requirement already satisfied: pandas in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from datasets->allennlp_models) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\elias\appdata\roaming\python\python310\site-packages (from datasets->allennlp_models) (3.3.0)
# Requirement already satisfied: multiprocess in c:\users\elias\appdata\roaming\python\python310\site-packages (from datasets->allennlp_models) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from datasets->allennlp_models) (2023.9.1)
# Requirement already satisfied: aiohttp in c:\users\elias\appdata\roaming\python\python310\site-packages (from datasets->allennlp_models) (3.8.5)
# Requirement already satisfied: packaging in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from datasets->allennlp_models) (23.1)
# Requirement already satisfied: responses<0.19 in c:\users\elias\appdata\roaming\python\python310\site-packages (from datasets->allennlp_models) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from datasets->allennlp_models) (6.0.1)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from ftfy->allennlp_models) (0.2.5)
# Requirement already satisfied: rich<13.0,>=12.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (12.6.0)
# Requirement already satisfied: boto3<2.0,>=1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (1.28.53)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (2.11.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from aiohttp->datasets->allennlp_models) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from aiohttp->datasets->allennlp_models) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\elias\appdata\roaming\python\python310\site-packages (from aiohttp->datasets->allennlp_models) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\elias\appdata\roaming\python\python310\site-packages (from aiohttp->datasets->allennlp_models) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from aiohttp->datasets->allennlp_models) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from aiohttp->datasets->allennlp_models) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from aiohttp->datasets->allennlp_models) (1.3.1)
# Requirement already satisfied: iniconfig in c:\users\elias\appdata\roaming\python\python310\site-packages (from pytest>=6.2.5->allennlp<2.11,>=2.10.1->allennlp_models) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\elias\appdata\roaming\python\python310\site-packages (from pytest>=6.2.5->allennlp<2.11,>=2.10.1->allennlp_models) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pytest>=6.2.5->allennlp<2.11,>=2.10.1->allennlp_models) (1.0.4)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from pytest>=6.2.5->allennlp<2.11,>=2.10.1->allennlp_models) (2.0.1)
# Requirement already satisfied: colorama in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pytest>=6.2.5->allennlp<2.11,>=2.10.1->allennlp_models) (0.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests>=2.28->allennlp<2.11,>=2.10.1->allennlp_models) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests>=2.28->allennlp<2.11,>=2.10.1->allennlp_models) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from requests>=2.28->allennlp<2.11,>=2.10.1->allennlp_models) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from scikit-learn>=1.0.1->allennlp<2.11,>=2.10.1->allennlp_models) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (2.0.9)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (1.8.2)
# Requirement already satisfied: jinja2 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (68.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (3.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from torchvision<0.14.0,>=0.8.1->allennlp<2.11,>=2.10.1->allennlp_models) (10.0.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from transformers<4.21,>=4.1->allennlp<2.11,>=2.10.1->allennlp_models) (0.12.1)
# Requirement already satisfied: GitPython>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp_models) (3.1.37)
# Requirement already satisfied: promise<3,>=2.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp_models) (2.3)
# Requirement already satisfied: shortuuid>=0.5.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp_models) (1.0.11)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp_models) (5.9.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp_models) (1.31.0)
# Requirement already satisfied: six>=1.13.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp_models) (1.16.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp_models) (0.4.0)
# Requirement already satisfied: pathtools in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp_models) (0.1.2)
# Requirement already satisfied: setproctitle in c:\users\elias\appdata\roaming\python\python310\site-packages (from wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp_models) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pandas->datasets->allennlp_models) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pandas->datasets->allennlp_models) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pandas->datasets->allennlp_models) (2023.3)
# Requirement already satisfied: botocore<1.32.0,>=1.31.53 in c:\users\elias\appdata\roaming\python\python310\site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (1.31.53)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from boto3<2.0,>=1.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (0.6.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp_models) (4.0.10)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (2.23.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (2.11.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.6.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (2.6.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from rich<13.0,>=12.1->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (2.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from jinja2->spacy<3.4,>=2.1.0->allennlp<2.11,>=2.10.1->allennlp_models) (2.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\elias\appdata\roaming\python\python310\site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb<0.13.0,>=0.10.0->allennlp<2.11,>=2.10.1->allennlp_models) (5.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (1.60.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\elias\appdata\roaming\python\python310\site-packages (from google-resumable-media>=2.6.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (1.5.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\elias\anaconda3\envs\nlp\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<1.2.0,>=1.1.3->allennlp<2.11,>=2.10.1->allennlp_models) (0.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch.nn as nn
from transformers import BertModel, BertTokenizer

# %%
class SentenceEncoder(nn.Module):
    def __init__(self, pretrained_model_name='bert-base-uncased'):
        super(SentenceEncoder, self).__init__()
        self.tokenizer = BertTokenizer.from_pretrained(pretrained_model_name)
        self.bert = BertModel.from_pretrained(pretrained_model_name)
        
    def forward(self, sentences):
        # Tokenize sentences
        inputs = self.tokenizer(sentences, return_tensors="pt", padding=True, truncation=True, max_length=512)
        # Get BERT embeddings
        outputs = self.bert(**inputs)
        # Use the average of token embeddings as the sentence representation
        sentence_embeddings = outputs.last_hidden_state.mean(dim=1)
        return sentence_embeddings

# %%
def get_view_representation(sentence_embeddings, spans):
    """
    sentence_embeddings: Tensor of shape [batch_size, embedding_dim]
    spans: List of tuples indicating the start and end indices of the span in the sentence
    """
    representations = []
    for i, (start, end) in enumerate(spans):
        span_embedding = sentence_embeddings[i, start:end].mean(dim=0)
        sentence_embedding = sentence_embeddings[i].mean()
        view_representation = torch.cat([span_embedding, sentence_embedding], dim=0)
        representations.append(view_representation)
    return torch.stack(representations)

# %%
class MultiViewFrameRepresentation(nn.Module):
    def __init__(self, input_dim, hidden_dim, K):
        super(MultiViewFrameRepresentation, self).__init__()
        self.Wh = nn.Linear(input_dim, hidden_dim)
        self.Wz_dict = nn.ModuleDict({
            'p': nn.Linear(hidden_dim, K),
            'a0': nn.Linear(hidden_dim, K),
            'a1': nn.Linear(hidden_dim, K)
        })
        self.Fz_dict = nn.ModuleDict({
            'p': nn.Embedding(K, input_dim // 2),
            'a0': nn.Embedding(K, input_dim // 2),
            'a1': nn.Embedding(K, input_dim // 2)
        })
        
    def forward(self, view_representation, view_type):
        h = torch.relu(self.Wh(view_representation))
        lz = self.Wz_dict[view_type](h)
        return lz
